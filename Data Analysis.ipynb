# %%
import pandas as pd
import numpy as np

# %%
from pyspark.sql import SparkSession

# Create/Get Spark session
spark = SparkSession.builder.appName("BankData").getOrCreate()

# %% [markdown]
# This is going to be a medalion architecture.
#
# ### Bronze :
# importing data from github
#
# ### Silver :
# cleaning and transforming the data
#
# ### Gold :
# Loading the final data into a database for quick use by business owners

# %%
# silver

df = spark.read.format("csv").option("header","True").option("inferSchema","True").load("/Workspace/Users/jerold1410@gmail.com/Banking-Data/bank.csv")
display(df)
